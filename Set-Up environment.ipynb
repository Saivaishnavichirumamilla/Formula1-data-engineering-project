# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `formula1_loc`
URL  'abfss://formula1@formula1adlssai.dfs.core.windows.net/'
WITH (CREDENTIAL `databricks-access-connector`)

# %%
# %fs ls 'abfss://formula1@formula1adlssai.dfs.core.windows.net/raw'

# %%
# %sql
DROP CATALOG IF EXISTS `dev_formula1`;
CREATE CATALOG   `dev_formula1`
    MANAGED LOCATION 'abfss://formula1@formula1adlssai.dfs.core.windows.net/'

# %%
# %sql SHOW CATALOGS

# %%
# %sql
USE CATALOG dev_formula1;
CREATE SCHEMA IF NOT EXISTS `raw`
    MANAGED LOCATION 'abfss://formula1@formula1adlssai.dfs.core.windows.net/raw'
